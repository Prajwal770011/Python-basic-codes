# %%
#List
print("LIST")
num=[10,20,65,235]
print(num)
num.append(22986520)
print("After append",num)
if 20 in num:
   num.remove(20)
print("After removal",num)
print("Firat number",num[0])
# Out:
# LIST
# [10, 20, 65, 235]
# After append [10, 20, 65, 235, 22986520]
# After removal [10, 65, 235, 22986520]
# Firat number 10

# %%
#Tuples
cod=(10.3,20.3,10.5)
print("Tuple:",cod)
print("First cord:",cod[0])
print("last cord:",cod[-1])
x,y,z=cod
print(f"Unpacked:x={x},y={y},z={z}")
# Out:
# Tuple: (10.3, 20.3, 10.5)
# First cord: 10.3
# last cord: 10.5
# Unpacked:x=10.3,y=20.3,z=10.5

# %%
#Create a list of 5 numbers and print aii elements
num=[915,988414562,9478,41651,11181]
print("ELEMENTS ")
print(num[0])
print(num[1])
print(num[2])
print(num[3])
print(num[4])
# Out:
# ELEMENTS
# 915
# 988414562
# 9478
# 41651
# 11181

# %%
#Print first and last element of a list[10,20,30,40,50]
inte=[10,20,30,40,50]
print("First elements",inte[0])
print("last elements",inte[-1])
# Out:
# First elements 10
# last elements 50

# %%
#Add number 100 to the list[1,2,3,4]
mum=[1,2,3,4]
mum.append(100)
print("After append",mum)
# Out:
# After append [1, 2, 3, 4, 100]

# %%
#Remove element 3 from list[1,2,3,4,5]
lol=[1,2,3,4,5]
if 3 in lol:
    lol.remove(3)
    print("After removal",lol)
# Out:
# After removal [1, 2, 4, 5]

# %%
#Find the sum of all elements in[5,10,15,20]
pop=[5,10,15,20]
list_sum = sum(pop)
print("The sum of elements is:", list_sum)
# Out:
# The sum of elements is: 50

# %%
#Find maximum and minimum in [8,3,9,1,6]
numbers = [8, 3, 9, 1, 6]
max_number = max(numbers)
min_number = min(numbers)

print("Maximum value is:", max_number)
print("Minimum value is:", min_number)
# Out:
# Maximum value is: 9
# Minimum value is: 1
